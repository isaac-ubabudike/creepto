# %%
### Step 1: Import necessary libraries

# %%
import pandas as pd # Data Transformatio
import requests # Establish connection with the API

# %%
url = "https://api.coincap.io/v2/assets"

# %%
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
responseData = response.json()
responseData
# Out:
# {'data': [{'id': 'bitcoin',
#    'rank': '1',
#    'symbol': 'BTC',
#    'name': 'Bitcoin',
#    'supply': '19712456.0000000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '1275281288696.3829619416614672',
#    'volumeUsd24Hr': '14180570131.2609388223126685',
#    'priceUsd': '64694.1856811948222962',
#    'changePercent24Hr': '-2.7641399840860026',
#    'vwap24Hr': '65356.8947343889293355',
#    'explorer': 'https://blockchain.info/'},
#   {'id': 'ethereum',
#    'rank': '2',
#    'symbol': 'ETH',
#    'name': 'Ethereum',
#    'supply': '120155065.8378261900000000',
#    'maxSupply': None,
#    'marketCapUsd': '413470522728.3945020622066917',
#    'volumeUsd24Hr': '9922297990.9760235603849082',
#    'priceUsd': '3441.1409943086165660',
#    'changePercent24Hr': '-2.3446333320163117',
#    'vwap24Hr': '3439.1600170042335559',
#    'explorer': 'https://etherscan.io/'},
#   {'id': 'tether',
#    'rank': '3',
#    'symbol': 'USDT',
#    'name': 'Tether',
#    'supply': '112559949271.1193700000000000',
#    'maxSupply': None,
#    'marketCapUsd': '112620301682.7236352296714144',
#    'volumeUsd24Hr': '24318625115.3766679453772541',
#    'priceUsd': '1.0005361801599510',
#    'changePercent24Hr': '0.0224517489154227',
#    'vwap24Hr': '1.0000683705887347',
#    'explorer': 'https://www.omniexplorer.info/asset/31'},
#   {'id': 'binance-coin',
#    'rank': '4',
#    'symbol': 'BNB',
#    'name': 'BNB',
#    'supply': '166801148.0000000000000000',
#    'maxSupply': '166801148.0000000000000000',
#    'marketCapUsd': '97325646314.9792112012458140',
#    'volumeUsd24Hr': '558747509.2695132502606161',
#    'priceUsd': '583.4830724005521305',
#    'changePercent24Hr': '-3.8703709497825942',
#    'vwap24Hr': '588.2794418423998908',
#    'explorer': 'https://etherscan.io/token/0xB8c77482e45F1F44dE1745F52C74426C631bDD52'},
#   {'id': 'solana',
#    'rank': '5',
#    'symbol': 'SOL',
#    'name': 'Solana',
#    'supply': '461692203.9830211000000000',
#    'maxSupply': None,
#    'marketCapUsd': '62689673531.5838326502084312',
#    'volumeUsd24Hr': '1350543922.2140239577840725',
#    'priceUsd': '135.7823956973058795',
#    'changePercent24Hr': '-5.2488381213590745',
#    'vwap24Hr': '136.8886001167931171',
#    'explorer': 'https://explorer.solana.com/'},
#   {'id': 'usd-coin',
#    'rank': '6',
#    'symbol': 'USDC',
#    'name': 'USDC',
#    'supply': '32441767268.1319430000000000',
#    'maxSupply': None,
#    'marketCapUsd': '32490385585.5574732926667345',
#    'volumeUsd24Hr': '1901169605.9206276588784823',
#    'priceUsd': '1.0014986334444637',
#    'changePercent24Hr': '0.0816888351813106',
#    'vwap24Hr': '1.0002748651200252',
#    'explorer': 'https://etherscan.io/token/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#   {'id': 'xrp',
#    'rank': '7',
#    'symbol': 'XRP',
#    'name': 'XRP',
#    'supply': '45404028640.0000000000000000',
#    'maxSupply': '100000000000.0000000000000000',
#    'marketCapUsd': '22001437934.4458933158683680',
#    'volumeUsd24Hr': '884245729.0486193213735794',
#    'priceUsd': '0.4845701712702887',
#    'changePercent24Hr': '-5.5316511914115079',
#    'vwap24Hr': '0.4945746069034360',
#    'explorer': 'https://xrpcharts.ripple.com/#/graph/'},
#   {'id': 'dogecoin',
#    'rank': '8',
#    'symbol': 'DOGE',
#    'name': 'Dogecoin',
#    'supply': '144724306383.7052000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '17479816554.7774900069774936',
#    'volumeUsd24Hr': '641288763.3537409136117729',
#    'priceUsd': '0.1207801024689905',
#    'changePercent24Hr': '-7.3718818552998109',
#    'vwap24Hr': '0.1228342686168806',
#    'explorer': 'http://dogechain.info/chain/Dogecoin'},
#   {'id': 'cardano',
#    'rank': '9',
#    'symbol': 'ADA',
#    'name': 'Cardano',
#    'supply': '35725385402.0400000000000000',
#    'maxSupply': '45000000000.0000000000000000',
#    'marketCapUsd': '13478581929.2472952620999775',
#    'volumeUsd24Hr': '291526708.5286047779613663',
#    'priceUsd': '0.3772830377493321',
#    'changePercent24Hr': '-7.6313916499319436',
#    'vwap24Hr': '0.3805819170723317',
#    'explorer': 'https://cardanoexplorer.com/'},
#   {'id': 'shiba-inu',
#    'rank': '10',
#    'symbol': 'SHIB',
#    'name': 'Shiba Inu',
#    'supply': '589271378849348.2000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '10573045491.9751647965777780',
#    'volumeUsd24Hr': '277694030.4261424896896775',
#    'priceUsd': '0.0000179425742900',
#    'changePercent24Hr': '-7.7073331765222784',
#    'vwap24Hr': '0.0000183019050663',
#    'explorer': 'https://etherscan.io/token/0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce'},
#   {'id': 'avalanche',
#    'rank': '11',
#    'symbol': 'AVAX',
#    'name': 'Avalanche',
#    'supply': '393329066.4362682000000000',
#    'maxSupply': '715748719.0000000000000000',
#    'marketCapUsd': '10369326284.0928130961921338',
#    'volumeUsd24Hr': '177507725.2574736954195925',
#    'priceUsd': '26.3629799293589030',
#    'changePercent24Hr': '-8.1140381255284165',
#    'vwap24Hr': '26.7624527776102279',
#    'explorer': 'https://avascan.info/'},
#   {'id': 'tron',
#    'rank': '12',
#    'symbol': 'TRX',
#    'name': 'TRON',
#    'supply': '87282705362.6485300000000000',
#    'maxSupply': None,
#    'marketCapUsd': '10063009979.2899792552471898',
#    'volumeUsd24Hr': '160994221.7124116462414480',
#    'priceUsd': '0.1152921410659701',
#    'changePercent24Hr': '-1.6246836745984666',
#    'vwap24Hr': '0.1152953861875403',
#    'explorer': 'https://tronscan.org/#/'},
#   {'id': 'wrapped-bitcoin',
#    'rank': '13',
#    'symbol': 'WBTC',
#    'name': 'Wrapped Bitcoin',
#    'supply': '153235.7378324500000000',
#    'maxSupply': None,
#    'marketCapUsd': '9920954503.7502556472275771',
#    'volumeUsd24Hr': '117030279.9818873822741847',
#    'priceUsd': '64743.0856801692021279',
#    'changePercent24Hr': '-2.5525409314429239',
#    'vwap24Hr': '65481.7266498364024167',
#    'explorer': 'https://etherscan.io/token/0x2260fac5e5542a773aa44fbcfedf7c193bc2c599'},
#   {'id': 'chainlink',
#    'rank': '14',
#    'symbol': 'LINK',
#    'name': 'Chainlink',
#    'supply': '587099970.4527867000000000',
#    'maxSupply': None,
#    'marketCapUsd': '7995727517.2956503974919566',
#    'volumeUsd24Hr': '326163695.5499206534162199',
#    'priceUsd': '13.6190221762899056',
#    'changePercent24Hr': '-6.8583549870471814',
#    'vwap24Hr': '13.7164872015647221',
#    'explorer': 'https://etherscan.io/token/0x514910771af9ca656af840dff83e8264ecf986ca'},
#   {'id': 'polkadot',
#    'rank': '15',
#    'symbol': 'DOT',
#    'name': 'Polkadot',
#    'supply': '1377727568.7916000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '7863503943.6744440206738953',
#    'volumeUsd24Hr': '181084098.9576254039058099',
#    'priceUsd': '5.7075898906280112',
#    'changePercent24Hr': '-7.7287106300717974',
#    'vwap24Hr': '5.8382725331812433',
#    'explorer': 'https://polkascan.io/polkadot'},
#   {'id': 'bitcoin-cash',
#    'rank': '16',
#    'symbol': 'BCH',
#    'name': 'Bitcoin Cash',
#    'supply': '19719903.1250000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '7521320387.9976125608527309',
#    'volumeUsd24Hr': '185606767.3205428823098730',
#    'priceUsd': '381.4075728628921731',
#    'changePercent24Hr': '-9.9446308166945189',
#    'vwap24Hr': '393.2375034669585372',
#    'explorer': 'https://blockchair.com/bitcoin-cash/blocks'},
#   {'id': 'uniswap',
#    'rank': '17',
#    'symbol': 'UNI',
#    'name': 'Uniswap',
#    'supply': '599957294.7100000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '5782279409.0549818943401377',
#    'volumeUsd24Hr': '152380410.8978521706108169',
#    'priceUsd': '9.6378183248025165',
#    'changePercent24Hr': '-11.1142773836128042',
#    'vwap24Hr': '9.9584247706585877',
#    'explorer': 'https://etherscan.io/token/0x1f9840a85d5af5bf1d1762f925bdaddc4201f984'},
#   {'id': 'polygon',
#    'rank': '18',
#    'symbol': 'MATIC',
#    'name': 'Polygon',
#    'supply': '9897485459.8402480000000000',
#    'maxSupply': None,
#    'marketCapUsd': '5404764363.4338349108890161',
#    'volumeUsd24Hr': '211540193.8764403433754664',
#    'priceUsd': '0.5460744939069677',
#    'changePercent24Hr': '-7.2589340083725017',
#    'vwap24Hr': '0.5550171727591576',
#    'explorer': 'https://etherscan.io/token/0x7D1AfA7B718fb893dB30A3aBc0Cfc608AaCfeBB0'},
#   {'id': 'litecoin',
#    'rank': '19',
#    'symbol': 'LTC',
#    'name': 'Litecoin',
#    'supply': '74646199.8575049000000000',
#    'maxSupply': '84000000.0000000000000000',
#    'marketCapUsd': '5379992405.9262961333950132',
#    'volumeUsd24Hr': '392523767.6189872502850618',
#    'priceUsd': '72.0732256457311642',
#    'changePercent24Hr': '-6.6422315395189032',
#    'vwap24Hr': '73.2939550113444721',
#    'explorer': 'http://explorer.litecoin.net/chain/Litecoin'},
#   {'id': 'multi-collateral-dai',
#    'rank': '20',
#    'symbol': 'DAI',
#    'name': 'Multi Collateral DAI',
#    'supply': '5347888595.7464075000000000',
#    'maxSupply': None,
#    'marketCapUsd': '5347534026.8563390022202304',
#    'volumeUsd24Hr': '576904899.6768277612745627',
#    'priceUsd': '0.9999336992751961',
#    'changePercent24Hr': '0.0388066604397981',
#    'vwap24Hr': '0.9997165104292754',
#    'explorer': 'https://etherscan.io/token/0x89d24a6b4ccb1b6faa2625fe562bdd9a23260359'},
#   {'id': 'unus-sed-leo',
#    'rank': '21',
#    'symbol': 'LEO',
#    'name': 'UNUS SED LEO',
#    'supply': '926206590.9000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '5330796517.1406155335388816',
#    'volumeUsd24Hr': '1490294.0592661400654338',
#    'priceUsd': '5.7555156371330196',
#    'changePercent24Hr': '0.6462860198381734',
#    'vwap24Hr': '5.7005669223495445',
#    'explorer': 'https://eospark.com/account/bitfinexleo1'},
#   {'id': 'near-protocol',
#    'rank': '22',
#    'symbol': 'NEAR',
#    'name': 'NEAR Protocol',
#    'supply': '1088588652.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '5083940303.4486800265893400',
#    'volumeUsd24Hr': '166041505.7170156140611245',
#    'priceUsd': '4.6702124756750450',
#    'changePercent24Hr': '-10.1583930327470382',
#    'vwap24Hr': '4.8065648349550513',
#    'explorer': 'https://explorer.nearprotocol.com/'},
#   {'id': 'internet-computer',
#    'rank': '23',
#    'symbol': 'ICP',
#    'name': 'Internet Computer',
#    'supply': '465246897.4002489400000000',
#    'maxSupply': None,
#    'marketCapUsd': '3783492455.8696704167340048',
#    'volumeUsd24Hr': '60480183.9344784674013827',
#    'priceUsd': '8.1322250121632858',
#    'changePercent24Hr': '-8.9520267837722134',
#    'vwap24Hr': '8.2203168477733564',
#    'explorer': 'https://www.dfinityexplorer.org/#/'},
#   {'id': 'ethereum-classic',
#    'rank': '24',
#    'symbol': 'ETC',
#    'name': 'Ethereum Classic',
#    'supply': '147534502.2732540700000000',
#    'maxSupply': '210700000.0000000000000000',
#    'marketCapUsd': '3380111858.6372903292099605',
#    'volumeUsd24Hr': '154266229.0281362733731080',
#    'priceUsd': '22.9106534848157824',
#    'changePercent24Hr': '-5.2247712761286724',
#    'vwap24Hr': '23.1112028397462653',
#    'explorer': 'http://gastracker.io/'},
#   {'id': 'monero',
#    'rank': '25',
#    'symbol': 'XMR',
#    'name': 'Monero',
#    'supply': '18446744.0737095500000000',
#    'maxSupply': None,
#    'marketCapUsd': '3138778683.3728454361862195',
#    'volumeUsd24Hr': '39241597.7607964000224505',
#    'priceUsd': '170.1535333732015287',
#    'changePercent24Hr': '-2.1792403840792052',
#    'vwap24Hr': '171.6223317981123273',
#    'explorer': 'http://moneroblocks.info/'},
#   {'id': 'render-token',
#    'rank': '26',
#    'symbol': 'RNDR',
#    'name': 'Render Token',
#    'supply': '369614008.1087959400000000',
#    'maxSupply': '536870912.0000000000000000',
#    'marketCapUsd': '2667221117.0213314461916279',
#    'volumeUsd24Hr': '22390133.4248985008050321',
#    'priceUsd': '7.2162338507371574',
#    'changePercent24Hr': '-8.6099248591288548',
#    'vwap24Hr': '7.3277172656628032',
#    'explorer': 'https://etherscan.io/token/0x6de037ef9ad2725eb40118bb1702ebb27e4aeb24'},
#   {'id': 'stellar',
#    'rank': '27',
#    'symbol': 'XLM',
#    'name': 'Stellar',
#    'supply': '29087026019.0048400000000000',
#    'maxSupply': '50001806812.0000000000000000',
#    'marketCapUsd': '2628825862.1966997865008644',
#    'volumeUsd24Hr': '73820227.2163739651761794',
#    'priceUsd': '0.0903779527160694',
#    'changePercent24Hr': '-7.5440342048830496',
#    'vwap24Hr': '0.0918758665967224',
#    'explorer': 'https://dashboard.stellar.org/'},
#   {'id': 'okb',
#    'rank': '28',
#    'symbol': 'OKB',
#    'name': 'OKB',
#    'supply': '60000000.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '2516937324.6451877040000000',
#    'volumeUsd24Hr': '875912.6044455016407714',
#    'priceUsd': '41.9489554107531284',
#    'changePercent24Hr': '-7.5719107872394891',
#    'vwap24Hr': '43.4463569873966456',
#    'explorer': 'https://etherscan.io/token/0x75231f58b43240c9718dd58b4967c5114342a86c'},
#   {'id': 'filecoin',
#    'rank': '29',
#    'symbol': 'FIL',
#    'name': 'Filecoin',
#    'supply': '563542035.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '2420695874.3438774897744325',
#    'volumeUsd24Hr': '174761015.8641067758120014',
#    'priceUsd': '4.2955018862858695',
#    'changePercent24Hr': '-13.4964814420611826',
#    'vwap24Hr': '4.4876969895893098',
#    'explorer': 'https://protocol.ai'},
#   {'id': 'stacks',
#    'rank': '30',
#    'symbol': 'STX',
#    'name': 'Stacks',
#    'supply': '1467232896.6689530000000000',
#    'maxSupply': '1818000000.0000000000000000',
#    'marketCapUsd': '2346184462.2522054172748023',
#    'volumeUsd24Hr': '37022746.9455180439508791',
#    'priceUsd': '1.5990538840689362',
#    'changePercent24Hr': '-8.9846184682767998',
#    'vwap24Hr': '1.6666738959608004',
#    'explorer': 'https://explorer.xinfin.network/'},
#   {'id': 'crypto-com-coin',
#    'rank': '31',
#    'symbol': 'CRO',
#    'name': 'Crypto.com Coin',
#    'supply': '25263013692.0000000000000000',
#    'maxSupply': '30263013692.0000000000000000',
#    'marketCapUsd': '2314725618.8413516302449712',
#    'volumeUsd24Hr': '10171901.8347592371410439',
#    'priceUsd': '0.0916250787440436',
#    'changePercent24Hr': '-3.6021479333080765',
#    'vwap24Hr': '0.0933196169761485',
#    'explorer': 'https://etherscan.io/token/0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b'},
#   {'id': 'maker',
#    'rank': '32',
#    'symbol': 'MKR',
#    'name': 'Maker',
#    'supply': '927898.0324557000000000',
#    'maxSupply': '1005577.0000000000000000',
#    'marketCapUsd': '2043807114.7040379741248997',
#    'volumeUsd24Hr': '48165880.1074965431763195',
#    'priceUsd': '2202.6203776885517395',
#    'changePercent24Hr': '-4.6492606465314761',
#    'vwap24Hr': '2208.4108502760942701',
#    'explorer': 'https://etherscan.io/token/Maker'},
#   {'id': 'the-graph',
#    'rank': '33',
#    'symbol': 'GRT',
#    'name': 'The Graph',
#    'supply': '9509975968.6355170000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1900283606.7057576473520026',
#    'volumeUsd24Hr': '42829348.5915505639455894',
#    'priceUsd': '0.1998200219404349',
#    'changePercent24Hr': '-8.2255510594876836',
#    'vwap24Hr': '0.2025807073884526',
#    'explorer': 'https://etherscan.io/token/0xc944e90c64b2c07662a292be6244bdf05cda44a7'},
#   {'id': 'lido-dao',
#    'rank': '34',
#    'symbol': 'LDO',
#    'name': 'Lido DAO',
#    'supply': '893005184.8907793000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1857054582.9445239582927911',
#    'volumeUsd24Hr': '16361339.3804520972045570',
#    'priceUsd': '2.0795563277403082',
#    'changePercent24Hr': '1.8571063713968571',
#    'vwap24Hr': '1.9982398451459600',
#    'explorer': 'https://etherscan.io/token/0x5a98fcbea516cf06857215779fd812ca3bef1b32'},
#   {'id': 'vechain',
#    'rank': '35',
#    'symbol': 'VET',
#    'name': 'VeChain',
#    'supply': '72714516834.0000000000000000',
#    'maxSupply': '86712634466.0000000000000000',
#    'marketCapUsd': '1815844856.0905593693754938',
#    'volumeUsd24Hr': '34057696.1894998069721157',
#    'priceUsd': '0.0249722467418157',
#    'changePercent24Hr': '-9.7694448527523850',
#    'vwap24Hr': '0.0254627110928644',
#    'explorer': 'https://explore.veforge.com/'},
#   {'id': 'arweave',
#    'rank': '36',
#    'symbol': 'AR',
#    'name': 'Arweave',
#    'supply': '65652466.0000000000000000',
#    'maxSupply': '66000000.0000000000000000',
#    'marketCapUsd': '1680886173.3199065398982806',
#    'volumeUsd24Hr': '39384754.8413730797048808',
#    'priceUsd': '25.6027880707467491',
#    'changePercent24Hr': '-5.2864308463651341',
#    'vwap24Hr': '25.2628574171861669',
#    'explorer': 'https://viewblock.io/arweave'},
#   {'id': 'cosmos',
#    'rank': '37',
#    'symbol': 'ATOM',
#    'name': 'Cosmos',
#    'supply': '248453201.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1623827857.3742724658873466',
#    'volumeUsd24Hr': '119415991.8316430947377228',
#    'priceUsd': '6.5357493919922266',
#    'changePercent24Hr': '-7.5368205403874562',
#    'vwap24Hr': '6.6081956043045508',
#    'explorer': 'https://www.mintscan.io/'},
#   {'id': 'injective-protocol',
#    'rank': '38',
#    'symbol': 'INJ',
#    'name': 'Injective',
#    'supply': '73005554.3300000000000000',
#    'maxSupply': '100000000.0000000000000000',
#    'marketCapUsd': '1482466904.0070380517606325',
#    'volumeUsd24Hr': '95976947.6774959368489696',
#    'priceUsd': '20.3062207747370179',
#    'changePercent24Hr': '-6.1346455128234815',
#    'vwap24Hr': '20.6382666122442174',
#    'explorer': 'https://etherscan.io/token/0xe28b3b32b6c345a34ff64674606124dd5aceca30'},
#   {'id': 'fantom',
#    'rank': '39',
#    'symbol': 'FTM',
#    'name': 'Fantom',
#    'supply': '2803634835.5265927000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1450245074.6684056126990534',
#    'volumeUsd24Hr': '177010114.2908849373569780',
#    'priceUsd': '0.5172731684923630',
#    'changePercent24Hr': '-12.2864257055671406',
#    'vwap24Hr': '0.5164482038799724',
#    'explorer': 'https://etherscan.io/token/0x4e15361fd6b4bb609fa63c81a2be19d873717870'},
#   {'id': 'theta',
#    'rank': '40',
#    'symbol': 'THETA',
#    'name': 'THETA',
#    'supply': '1000000000.0000000000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '1381400084.1903956000000000',
#    'volumeUsd24Hr': '23234778.2062189131872431',
#    'priceUsd': '1.3814000841903956',
#    'changePercent24Hr': '-10.9091588358522468',
#    'vwap24Hr': '1.4334360006234324',
#    'explorer': 'https://explorer.thetatoken.org/'},
#   {'id': 'thorchain',
#    'rank': '41',
#    'symbol': 'RUNE',
#    'name': 'THORChain',
#    'supply': '335448842.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1334611123.6400998971825624',
#    'volumeUsd24Hr': '83719880.6516968721293462',
#    'priceUsd': '3.9785831892664572',
#    'changePercent24Hr': '-8.9775317083558448',
#    'vwap24Hr': '4.0523483848878537',
#    'explorer': 'https://explorer.binance.org/asset/RUNE-B1A'},
#   {'id': 'aave',
#    'rank': '42',
#    'symbol': 'AAVE',
#    'name': 'Aave',
#    'supply': '14849689.3724249100000000',
#    'maxSupply': None,
#    'marketCapUsd': '1194463441.9771925065283547',
#    'volumeUsd24Hr': '53615276.0989760436716675',
#    'priceUsd': '80.4369311721259384',
#    'changePercent24Hr': '-6.5297825603176592',
#    'vwap24Hr': '80.5322172885465492',
#    'explorer': 'https://etherscan.io/token/0x80fB784B7eD66730e8b1DBd9820aFD29931aab03'},
#   {'id': 'hedera-hashgraph',
#    'rank': '43',
#    'symbol': 'HBAR',
#    'name': 'Hedera Hashgraph',
#    'supply': '14832756028.0000000000000000',
#    'maxSupply': '50000000000.0000000000000000',
#    'marketCapUsd': '1136236765.6067300926956236',
#    'volumeUsd24Hr': '36568751.2246607887986014',
#    'priceUsd': '0.0766032127449437',
#    'changePercent24Hr': '-6.2069335153032585',
#    'vwap24Hr': '0.0768498897126659',
#    'explorer': 'https://hash-hash.info/'},
#   {'id': 'algorand',
#    'rank': '44',
#    'symbol': 'ALGO',
#    'name': 'Algorand',
#    'supply': '8181490851.8740910000000000',
#    'maxSupply': '10000000000.0000000000000000',
#    'marketCapUsd': '1073878463.3582776428343397',
#    'volumeUsd24Hr': '57875058.5196989489904388',
#    'priceUsd': '0.1312570633886720',
#    'changePercent24Hr': '-10.7978979065631711',
#    'vwap24Hr': '0.1366123032651069',
#    'explorer': 'https://algoexplorer.io/'},
#   {'id': 'fetch',
#    'rank': '45',
#    'symbol': 'FET',
#    'name': 'Fetch.ai',
#    'supply': '848193895.9129184000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1001696956.5588598168515337',
#    'volumeUsd24Hr': '112264719.4465194726260264',
#    'priceUsd': '1.1809763797942978',
#    'changePercent24Hr': '-11.8194301898829270',
#    'vwap24Hr': '1.2125397857622897',
#    'explorer': 'https://etherscan.io/token/0x1d287cc25dad7ccaf76a26bc660c5f7c8e2a05bd'},
#   {'id': 'kucoin-token',
#    'rank': '46',
#    'symbol': 'KCS',
#    'name': 'KuCoin Token',
#    'supply': '95642961.2885607500000000',
#    'maxSupply': '170118638.0000000000000000',
#    'marketCapUsd': '928044350.2799772953031938',
#    'volumeUsd24Hr': '1102967.8631421691835646',
#    'priceUsd': '9.7032163974932760',
#    'changePercent24Hr': '-3.7972644969028731',
#    'vwap24Hr': '9.8219078633113306',
#    'explorer': 'https://etherscan.io/token/0xf34960d9d60be18cc1d5afc1a6f012a723a28811'},
#   {'id': 'quant',
#    'rank': '47',
#    'symbol': 'QNT',
#    'name': 'Quant',
#    'supply': '12072738.0000000000000000',
#    'maxSupply': '14881364.0000000000000000',
#    'marketCapUsd': '915531006.0658645173786966',
#    'volumeUsd24Hr': '9684853.8631127641056427',
#    'priceUsd': '75.8345792036458107',
#    'changePercent24Hr': '-6.3289354839668550',
#    'vwap24Hr': '76.1969767603178404',
#    'explorer': 'https://etherscan.io/token/0x4a220e6096b25eadb88358cb44068a3248254675'},
#   {'id': 'flow',
#    'rank': '48',
#    'symbol': 'FLOW',
#    'name': 'Flow',
#    'supply': '1511780104.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '884915076.3787842190283880',
#    'volumeUsd24Hr': '26179913.1578567969208779',
#    'priceUsd': '0.5853464230924845',
#    'changePercent24Hr': '-13.5465889186293405',
#    'vwap24Hr': '0.6128459327116363',
#    'explorer': 'https://flowscan.org/'},
#   {'id': 'gala',
#    'rank': '49',
#    'symbol': 'GALA',
#    'name': 'Gala',
#    'supply': '31692090315.8466260000000000',
#    'maxSupply': None,
#    'marketCapUsd': '845292546.8048483653926188',
#    'volumeUsd24Hr': '56335696.9138815604691253',
#    'priceUsd': '0.0266720351475897',
#    'changePercent24Hr': '-10.9701587740385532',
#    'vwap24Hr': '0.0277810803968331',
#    'explorer': 'https://ethplorer.io/es/address/0x15d4c048f83bd7e37d49ea4c83a07267ec4203da#chart=candlestick'},
#   {'id': 'bitcoin-sv',
#    'rank': '50',
#    'symbol': 'BSV',
#    'name': 'Bitcoin SV',
#    'supply': '19715793.7500000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '833676006.4979240133528244',
#    'volumeUsd24Hr': '9919575.3319159068389453',
#    'priceUsd': '42.2846788249610297',
#    'changePercent24Hr': '-12.2831449196201600',
#    'vwap24Hr': '44.0878001942012405',
#    'explorer': 'https://bsvexplorer.io/'},
#   {'id': 'axie-infinity',
#    'rank': '51',
#    'symbol': 'AXS',
#    'name': 'Axie Infinity',
#    'supply': '145852262.7463052600000000',
#    'maxSupply': None,
#    'marketCapUsd': '828604283.2064081354447350',
#    'volumeUsd24Hr': '27544268.9176757409078047',
#    'priceUsd': '5.6811205229477895',
#    'changePercent24Hr': '-9.9955188491672894',
#    'vwap24Hr': '5.8636577000822946',
#    'explorer': 'https://etherscan.io/token/0xf5d669627376ebd411e34b98f19c868c8aba5ada'},
#   {'id': 'gnosis-gno',
#    'rank': '52',
#    'symbol': 'GNO',
#    'name': 'Gnosis',
#    'supply': '2589588.0000000000000000',
#    'maxSupply': '3000000.0000000000000000',
#    'marketCapUsd': '801451628.3105382068467488',
#    'volumeUsd24Hr': '13474259.5385853666687741',
#    'priceUsd': '309.4900147477275176',
#    'changePercent24Hr': '-4.6457819214828658',
#    'vwap24Hr': '307.4874158043030891',
#    'explorer': 'https://etherscan.io/token/Gnosis'},
#   {'id': 'pendle',
#    'rank': '53',
#    'symbol': 'PENDLE',
#    'name': 'Pendle',
#    'supply': '154379404.8541060700000000',
#    'maxSupply': None,
#    'marketCapUsd': '761074160.1326295705336263',
#    'volumeUsd24Hr': '6335855.2340462887806253',
#    'priceUsd': '4.9298943784105868',
#    'changePercent24Hr': '-6.8002581427144507',
#    'vwap24Hr': '5.1270304206286292',
#    'explorer': 'https://etherscan.io/token/0x808507121b80c02388fad14726482e061b8da827'},
#   {'id': 'neo',
#    'rank': '54',
#    'symbol': 'NEO',
#    'name': 'Neo',
#    'supply': '70538831.0000000000000000',
#    'maxSupply': '100000000.0000000000000000',
#    'marketCapUsd': '758762334.3797282303965590',
#    'volumeUsd24Hr': '22871155.1086040309881400',
#    'priceUsd': '10.7566615950826890',
#    'changePercent24Hr': '-9.4457105358409695',
#    'vwap24Hr': '11.0772741178237594',
#    'explorer': 'https://neotracker.io'},
#   {'id': 'gatetoken',
#    'rank': '55',
#    'symbol': 'GT',
#    'name': 'GateToken',
#    'supply': '93211457.9314358800000000',
#    'maxSupply': None,
#    'marketCapUsd': '728711090.8970693634689317',
#    'volumeUsd24Hr': '7871975.6374494633460448',
#    'priceUsd': '7.8178274116588952',
#    'changePercent24Hr': '-6.1956143135464706',
#    'vwap24Hr': '8.2175560457601782',
#    'explorer': None},
#   {'id': 'tezos',
#    'rank': '56',
#    'symbol': 'XTZ',
#    'name': 'Tezos',
#    'supply': '985424982.0762660000000000',
#    'maxSupply': None,
#    'marketCapUsd': '719031771.3731247747186469',
#    'volumeUsd24Hr': '29461870.5532259343205822',
#    'priceUsd': '0.7296666762579356',
#    'changePercent24Hr': '-4.7130574078015879',
#    'vwap24Hr': '0.7287135318155631',
#    'explorer': 'https://tzkt.io/'},
#   {'id': 'chiliz',
#    'rank': '57',
#    'symbol': 'CHZ',
#    'name': 'Chiliz',
#    'supply': '8888289967.1249620000000000',
#    'maxSupply': None,
#    'marketCapUsd': '711006769.8615647819149125',
#    'volumeUsd24Hr': '70286645.7638963661992883',
#    'priceUsd': '0.0799936514775462',
#    'changePercent24Hr': '-13.1582484166766838',
#    'vwap24Hr': '0.0829262315829031',
#    'explorer': 'https://etherscan.io/token/0x3506424f91fd33084466f402d5d97f05f8e3b4af'},
#   {'id': 'nexo',
#    'rank': '58',
#    'symbol': 'NEXO',
#    'name': 'Nexo',
#    'supply': '560000011.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '697432428.2614635740372878',
#    'volumeUsd24Hr': '1809908.4246440246068172',
#    'priceUsd': '1.2454150260033898',
#    'changePercent24Hr': '-5.6115804366544857',
#    'vwap24Hr': '1.2675652964068577',
#    'explorer': 'https://etherscan.io/token/0xb62132e35a6c13ee1ee0f84dc5d40bad8d815206'},
#   {'id': 'the-sandbox',
#    'rank': '59',
#    'symbol': 'SAND',
#    'name': 'The Sandbox',
#    'supply': '2281231926.2233224000000000',
#    'maxSupply': None,
#    'marketCapUsd': '697202772.6155006063117510',
#    'volumeUsd24Hr': '39618707.1094755197078962',
#    'priceUsd': '0.3056255545966121',
#    'changePercent24Hr': '-11.4462572223857033',
#    'vwap24Hr': '0.3179685032466675',
#    'explorer': 'https://etherscan.io/token/0x3845badAde8e6dFF049820680d1F14bD3903a5d0'},
#   {'id': 'elrond-egld',
#    'rank': '60',
#    'symbol': 'EGLD',
#    'name': 'MultiversX',
#    'supply': '24184559.1898415400000000',
#    'maxSupply': '31415926.0000000000000000',
#    'marketCapUsd': '696326145.4142193153720361',
#    'volumeUsd24Hr': '25110921.9743325641944366',
#    'priceUsd': '28.7921785114323485',
#    'changePercent24Hr': '-7.9945674340823967',
#    'vwap24Hr': '28.8878009839503265',
#    'explorer': 'https://explorer.elrond.com/'},
#   {'id': 'oasis-network',
#    'rank': '61',
#    'symbol': 'ROSE',
#    'name': 'Oasis',
#    'supply': '6713599876.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '640551018.5193036472152308',
#    'volumeUsd24Hr': '22107684.5837317183915490',
#    'priceUsd': '0.0954109613843933',
#    'changePercent24Hr': '-8.4349072153692996',
#    'vwap24Hr': '0.0988590002760867',
#    'explorer': 'https://www.oasisscan.com/'},
#   {'id': 'singularitynet',
#    'rank': '62',
#    'symbol': 'AGIX',
#    'name': 'SingularityNET',
#    'supply': '1287276446.6453247000000000',
#    'maxSupply': '2000000000.0000000000000000',
#    'marketCapUsd': '637122950.0684535695324201',
#    'volumeUsd24Hr': '5645901.1262154120771957',
#    'priceUsd': '0.4949387147794184',
#    'changePercent24Hr': '-11.4024140840161270',
#    'vwap24Hr': '0.5087666245696210',
#    'explorer': 'https://etherscan.io/token/0x8eb24319393716668d768dcec29356ae9cffe285'},
#   {'id': 'akash-network',
#    'rank': '63',
#    'symbol': 'AKT',
#    'name': 'Akash Network',
#    'supply': '240592142.7481850000000000',
#    'maxSupply': '388539008.0000000000000000',
#    'marketCapUsd': '620674025.2842172372638740',
#    'volumeUsd24Hr': '7667498.7396600982141455',
#    'priceUsd': '2.5797767881964613',
#    'changePercent24Hr': '-15.0801773522014655',
#    'vwap24Hr': '2.8736243064667961',
#    'explorer': 'https://akash.bigdipper.live/'},
#   {'id': 'dexe',
#    'rank': '64',
#    'symbol': 'DEXE',
#    'name': 'DeXe',
#    'supply': '57103104.2075166100000000',
#    'maxSupply': '98942301.0000000000000000',
#    'marketCapUsd': '617997373.5296280541942931',
#    'volumeUsd24Hr': '1461353.9201557569002641',
#    'priceUsd': '10.8224829824274189',
#    'changePercent24Hr': '-7.3694296470902791',
#    'vwap24Hr': '11.4982264846065402',
#    'explorer': 'https://etherscan.io/token/0xde4EE8057785A7e8e800Db58F9784845A5C2Cbd6'},
#   {'id': 'eos',
#    'rank': '65',
#    'symbol': 'EOS',
#    'name': 'EOS',
#    'supply': '1127540931.1325000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '615865359.4515700846331340',
#    'volumeUsd24Hr': '139719683.1766125305434705',
#    'priceUsd': '0.5462022197571099',
#    'changePercent24Hr': '-12.2867141004674067',
#    'vwap24Hr': '0.5694396078909481',
#    'explorer': 'https://bloks.io/'},
#   {'id': 'decentraland',
#    'rank': '66',
#    'symbol': 'MANA',
#    'name': 'Decentraland',
#    'supply': '1908319865.3915880000000000',
#    'maxSupply': None,
#    'marketCapUsd': '610024802.5473855986315729',
#    'volumeUsd24Hr': '22882001.7987330159689339',
#    'priceUsd': '0.3196659080118145',
#    'changePercent24Hr': '-10.4688220086903284',
#    'vwap24Hr': '0.3262346875558969',
#    'explorer': 'https://etherscan.io/token/decentraland'},
#   {'id': 'ecash',
#    'rank': '67',
#    'symbol': 'XEC',
#    'name': 'eCash',
#    'supply': '19715867173092.0000000000000000',
#    'maxSupply': '21000000000000.0000000000000000',
#    'marketCapUsd': '607276655.7490603136885220',
#    'volumeUsd24Hr': '7200147.9777626252992415',
#    'priceUsd': '0.0000308014174785',
#    'changePercent24Hr': '-8.6945803749617429',
#    'vwap24Hr': '0.0000314270382277',
#    'explorer': 'https://explorer.bitcoinabc.org/'},
#   {'id': 'mina',
#    'rank': '68',
#    'symbol': 'MINA',
#    'name': 'Mina',
#    'supply': '1120076928.8400393000000000',
#    'maxSupply': None,
#    'marketCapUsd': '605889189.6574965813726921',
#    'volumeUsd24Hr': '16998812.2733152659226933',
#    'priceUsd': '0.5409353358299776',
#    'changePercent24Hr': '-10.7736629184461314',
#    'vwap24Hr': '0.5543312350459002',
#    'explorer': 'https://minaexplorer.com/'},
#   {'id': 'conflux-network',
#    'rank': '69',
#    'symbol': 'CFX',
#    'name': 'Conflux',
#    'supply': '4135995199.9900000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '599081726.9744055687046316',
#    'volumeUsd24Hr': '41084449.4261535518311855',
#    'priceUsd': '0.1448458467688391',
#    'changePercent24Hr': '-19.9637157299179167',
#    'vwap24Hr': '0.1573825708703275',
#    'explorer': 'http://www.confluxscan.io/'},
#   {'id': 'klaytn',
#    'rank': '70',
#    'symbol': 'KLAY',
#    'name': 'Klaytn',
#    'supply': '3695558723.5308113000000000',
#    'maxSupply': None,
#    'marketCapUsd': '592205886.3422109402743150',
#    'volumeUsd24Hr': '8334447.1922050686261433',
#    'priceUsd': '0.1602479978389859',
#    'changePercent24Hr': '-4.0826089740792278',
#    'vwap24Hr': '0.1597276160179605',
#    'explorer': 'https://scope.klaytn.com/blocks'},
#   {'id': 'livepeer',
#    'rank': '71',
#    'symbol': 'LPT',
#    'name': 'Livepeer',
#    'supply': '32786832.9379033500000000',
#    'maxSupply': None,
#    'marketCapUsd': '588985727.4100063124519475',
#    'volumeUsd24Hr': '35792467.7456784532842856',
#    'priceUsd': '17.9640933458109946',
#    'changePercent24Hr': '-11.9997501126028869',
#    'vwap24Hr': '18.9203254194529285',
#    'explorer': 'https://explorer.livepeer.org/'},
#   {'id': 'pancakeswap',
#    'rank': '72',
#    'symbol': 'CAKE',
#    'name': 'PancakeSwap',
#    'supply': '266833789.0488574000000000',
#    'maxSupply': '450000000.0000000000000000',
#    'marketCapUsd': '586007948.6096495045514445',
#    'volumeUsd24Hr': '28435214.1352314842999471',
#    'priceUsd': '2.1961534582951605',
#    'changePercent24Hr': '-10.9245762417731678',
#    'vwap24Hr': '2.2624150314036578',
#    'explorer': 'https://bscscan.com/token/0x0e09fabb73bd3ade0a17ecc321fd13a19e81ce82'},
#   {'id': 'rocket-pool',
#    'rank': '73',
#    'symbol': 'RPL',
#    'name': 'Rocket Pool',
#    'supply': '20445460.3785531500000000',
#    'maxSupply': None,
#    'marketCapUsd': '544062859.4806023426197819',
#    'volumeUsd24Hr': '3185601.3794876518591430',
#    'priceUsd': '26.6104479628794580',
#    'changePercent24Hr': '-0.8322888968288417',
#    'vwap24Hr': '26.3836458328856967',
#    'explorer': 'https://etherscan.io/token/0xb4efd85c19999d84251304bda99e90b92300bd93'},
#   {'id': 'iota',
#    'rank': '74',
#    'symbol': 'IOTA',
#    'name': 'IOTA',
#    'supply': '3306056194.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '539885650.0003131877896772',
#    'volumeUsd24Hr': '12984196.4975876446602158',
#    'priceUsd': '0.1633020185743138',
#    'changePercent24Hr': '-7.5948373057000585',
#    'vwap24Hr': '0.1640553701593739',
#    'explorer': 'https://thetangle.org/'},
#   {'id': 'ftx-token',
#    'rank': '75',
#    'symbol': 'FTT',
#    'name': 'FTX Token',
#    'supply': '328895103.8132070000000000',
#    'maxSupply': None,
#    'marketCapUsd': '528880478.5837141501846033',
#    'volumeUsd24Hr': '33917221.3738980263018303',
#    'priceUsd': '1.6080521493080269',
#    'changePercent24Hr': '9.7537932332033639',
#    'vwap24Hr': '1.4791801191987461',
#    'explorer': 'https://etherscan.io/token/0x50d1c9771902476076ecfc8b2a83ad6b9355a4c9'},
#   {'id': 'helium',
#    'rank': '76',
#    'symbol': 'HNT',
#    'name': 'Helium',
#    'supply': '160875441.8242133300000000',
#    'maxSupply': None,
#    'marketCapUsd': '519289752.8560754103086202',
#    'volumeUsd24Hr': '2563920.3902926896375392',
#    'priceUsd': '3.2278994666165213',
#    'changePercent24Hr': '1.9455088692124628',
#    'vwap24Hr': '3.0907497728358390',
#    'explorer': 'https://explorer.helium.com/'},
#   {'id': 'aioz-network',
#    'rank': '77',
#    'symbol': 'AIOZ',
#    'name': 'AIOZ Network',
#    'supply': '1100736159.7078450000000000',
#    'maxSupply': None,
#    'marketCapUsd': '518007172.1400308051493230',
#    'volumeUsd24Hr': '6181641.7346615413460755',
#    'priceUsd': '0.4706006680815493',
#    'changePercent24Hr': '-14.2540547359212704',
#    'vwap24Hr': '0.5187275188077286',
#    'explorer': 'https://etherscan.io/token/0x626e8036deb333b408be468f951bdb42433cbf18'},
#   {'id': '1inch',
#    'rank': '78',
#    'symbol': '1INCH',
#    'name': '1inch Network',
#    'supply': '1251717710.0126850000000000',
#    'maxSupply': None,
#    'marketCapUsd': '498240663.8648640089721843',
#    'volumeUsd24Hr': '45436446.0885335193202010',
#    'priceUsd': '0.3980455496310065',
#    'changePercent24Hr': '1.7300807467311481',
#    'vwap24Hr': '0.3874115812728496',
#    'explorer': 'https://etherscan.io/token/0x111111111117dc0aa78b770fa6a738034120c302'},
#   {'id': 'trueusd',
#    'rank': '79',
#    'symbol': 'TUSD',
#    'name': 'TrueUSD',
#    'supply': '495701483.8100000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '494050304.4354253223861043',
#    'volumeUsd24Hr': '9388719.3728451035898272',
#    'priceUsd': '0.9966690045753271',
#    'changePercent24Hr': '-0.0610551127991975',
#    'vwap24Hr': '0.9976450097661244',
#    'explorer': 'https://etherscan.io/token/0x8dd5fbce2f6a956c3022ba3663759011dd51e73e'},
#   {'id': 'nxm',
#    'rank': '80',
#    'symbol': 'NXM',
#    'name': 'NXM',
#    'supply': '6594067.8412913900000000',
#    'maxSupply': None,
#    'marketCapUsd': '487936748.3863349940860997',
#    'volumeUsd24Hr': '29758245.1347711223080465',
#    'priceUsd': '73.9963191356516113',
#    'changePercent24Hr': '1.8919551911911605',
#    'vwap24Hr': '73.2362140334809523',
#    'explorer': 'https://etherscan.io/token/0xd7c49cee7e9188cca6ad8ff264c1da2e69d4cf3b'},
#   {'id': 'kava',
#    'rank': '81',
#    'symbol': 'KAVA',
#    'name': 'Kava',
#    'supply': '1082856222.0000000000000000',
#    'maxSupply': '1082860679.0000000000000000',
#    'marketCapUsd': '480002507.4441635472971250',
#    'volumeUsd24Hr': '12519830.7461021140007854',
#    'priceUsd': '0.4432744603504375',
#    'changePercent24Hr': '-13.7053035980316185',
#    'vwap24Hr': '0.4575443110837888',
#    'explorer': 'https://www.mintscan.io/kava'},
#   {'id': 'nervos-network',
#    'rank': '82',
#    'symbol': 'CKB',
#    'name': 'Nervos Network',
#    'supply': '44359932782.2433500000000000',
#    'maxSupply': None,
#    'marketCapUsd': '459112481.3780094349029321',
#    'volumeUsd24Hr': '24456856.7561532405401157',
#    'priceUsd': '0.0103497109346790',
#    'changePercent24Hr': '-13.1701326810554530',
#    'vwap24Hr': '0.0108831904363534',
#    'explorer': 'https://explorer.nervos.org/'},
#   {'id': 'theta-fuel',
#    'rank': '83',
#    'symbol': 'TFUEL',
#    'name': 'Theta Fuel',
#    'supply': '6582187591.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '447367723.0853430057538003',
#    'volumeUsd24Hr': '4861631.2883875175805098',
#    'priceUsd': '0.0679664195072533',
#    'changePercent24Hr': '-8.8033786941842342',
#    'vwap24Hr': '0.0690547471343082',
#    'explorer': 'https://explorer.thetatoken.org/'},
#   {'id': 'synthetix-network-token',
#    'rank': '84',
#    'symbol': 'SNX',
#    'name': 'Synthetix',
#    'supply': '233716733.4900000000000000',
#    'maxSupply': '212424133.0000000000000000',
#    'marketCapUsd': '437290695.1622623094766151',
#    'volumeUsd24Hr': '25719647.9368655506157032',
#    'priceUsd': '1.8710286107133728',
#    'changePercent24Hr': '-7.5243460037472478',
#    'vwap24Hr': '1.8967992054979553',
#    'explorer': 'https://etherscan.io/token/0xc011a72400e58ecd99ee497cf89e3775d4bd732f'},
#   {'id': 'xinfin-network',
#    'rank': '85',
#    'symbol': 'XDC',
#    'name': 'XinFin Network',
#    'supply': '12293293518.5500000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '427113591.0053541574902529',
#    'volumeUsd24Hr': '1517261.1252659327927901',
#    'priceUsd': '0.0347436258933263',
#    'changePercent24Hr': '3.7761466568949912',
#    'vwap24Hr': '0.0334154246415974',
#    'explorer': 'https://etherscan.io/token/0x41ab1b6fcbb2fa9dced81acbdec13ea6315f2bf2'},
#   {'id': 'iotex',
#    'rank': '86',
#    'symbol': 'IOTX',
#    'name': 'IoTeX',
#    'supply': '9441378929.0000000000000000',
#    'maxSupply': '10000000000.0000000000000000',
#    'marketCapUsd': '411195824.4828760628390845',
#    'volumeUsd24Hr': '19991965.4750373600716907',
#    'priceUsd': '0.0435525178657805',
#    'changePercent24Hr': '-14.7062275236087017',
#    'vwap24Hr': '0.0498652833574597',
#    'explorer': 'https://etherscan.io/token/0x6fb3e0a217407efff7ca062d46c26e5d60a14d69'},
#   {'id': 'trust-wallet-token',
#    'rank': '87',
#    'symbol': 'TWT',
#    'name': 'Trust Wallet Token',
#    'supply': '416649900.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '406757096.5785681118416900',
#    'volumeUsd24Hr': '7702237.6989067773749820',
#    'priceUsd': '0.9762563163427331',
#    'changePercent24Hr': '-9.3766653903463356',
#    'vwap24Hr': '0.9934309937292737',
#    'explorer': 'https://explorer.binance.org/asset/TWT-8C2'},
#   {'id': 'curve-dao-token',
#    'rank': '88',
#    'symbol': 'CRV',
#    'name': 'Curve DAO Token',
#    'supply': '1254246792.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '399723126.2271882391880424',
#    'volumeUsd24Hr': '31521033.8119815291797403',
#    'priceUsd': '0.3186957533212397',
#    'changePercent24Hr': '-1.3096570688022060',
#    'vwap24Hr': '0.3020254610770453',
#    'explorer': 'https://etherscan.io/token/0xD533a949740bb3306d119CC777fa900bA034cd52'},
#   {'id': 'wootrade',
#    'rank': '89',
#    'symbol': 'WOO',
#    'name': 'WOO',
#    'supply': '1893435561.4090352000000000',
#    'maxSupply': None,
#    'marketCapUsd': '394589879.6265692326018164',
#    'volumeUsd24Hr': '13094423.6618677801475525',
#    'priceUsd': '0.2083988954622400',
#    'changePercent24Hr': '-9.9065353050693435',
#    'vwap24Hr': '0.2135928167404277',
#    'explorer': 'https://etherscan.io/token/0x4691937a7508860f876c9c0a2a617e7d9e945d4b'},
#   {'id': 'compound',
#    'rank': '90',
#    'symbol': 'COMP',
#    'name': 'Compound',
#    'supply': '8358340.3269927900000000',
#    'maxSupply': None,
#    'marketCapUsd': '392581066.4573422975568665',
#    'volumeUsd24Hr': '39543501.0220982628713646',
#    'priceUsd': '46.9687822102103001',
#    'changePercent24Hr': '-8.3524032189687296',
#    'vwap24Hr': '47.4777346882956853',
#    'explorer': 'https://etherscan.io/token/0xc00e94cb662c3520282e6f5717214004a7f26888'},
#   {'id': 'raydium',
#    'rank': '91',
#    'symbol': 'RAY',
#    'name': 'Raydium',
#    'supply': '262914235.5522840000000000',
#    'maxSupply': None,
#    'marketCapUsd': '377960933.2426221527511136',
#    'volumeUsd24Hr': '7959795.1155670393748507',
#    'priceUsd': '1.4375826111076423',
#    'changePercent24Hr': '-10.3796803819792347',
#    'vwap24Hr': '1.5250010434527278',
#    'explorer': 'https://explorer.solana.com/address/4k3Dyjzvzp8eMZWUXbBCjEvwSkkk59S5iCNLY3QrkX6R'},
#   {'id': 'wemix',
#    'rank': '92',
#    'symbol': 'WEMIX',
#    'name': 'WEMIX',
#    'supply': '362785599.9918850700000000',
#    'maxSupply': '980000000.0000000000000000',
#    'marketCapUsd': '373065937.2752785633037978',
#    'volumeUsd24Hr': '7919528.7801428694127034',
#    'priceUsd': '1.0283372253022817',
#    'changePercent24Hr': '3.7109957525541382',
#    'vwap24Hr': '1.0157816483598008',
#    'explorer': 'https://scope.klaytn.com/token/0x5096db80b21ef45230c9e423c373f1fc9c0198dd?tabId=kctTransfer'},
#   {'id': 'aragon',
#    'rank': '93',
#    'symbol': 'ANT',
#    'name': 'Aragon',
#    'supply': '43179902.2896615100000000',
#    'maxSupply': None,
#    'marketCapUsd': '371383969.9675529937926938',
#    'volumeUsd24Hr': '4118199.1353697318239689',
#    'priceUsd': '8.6008524863307257',
#    'changePercent24Hr': '-3.3457919134815461',
#    'vwap24Hr': '8.8014928493928668',
#    'explorer': 'https://etherscan.io/token/Aragon'},
#   {'id': 'golem-network-tokens',
#    'rank': '94',
#    'symbol': 'GLM',
#    'name': 'Golem',
#    'supply': '1000000000.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '361909976.7320850000000000',
#    'volumeUsd24Hr': '3192582.4754306561641104',
#    'priceUsd': '0.3619099767320850',
#    'changePercent24Hr': '-6.0000784487539132',
#    'vwap24Hr': '0.3804584177567666',
#    'explorer': 'https://etherscan.io/token/Golem'},
#   {'id': 'blox',
#    'rank': '95',
#    'symbol': 'CDT',
#    'name': 'Blox',
#    'supply': '1000000000.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '361024763.3232858000000000',
#    'volumeUsd24Hr': '265465.3816912266281673',
#    'priceUsd': '0.3610247633232858',
#    'changePercent24Hr': '-3.0240320757529466',
#    'vwap24Hr': None,
#    'explorer': 'https://etherscan.io/token/0x177d39ac676ed1c67a2b268ad7f1e58826e5b0af'},
#   {'id': 'convex-finance',
#    'rank': '96',
#    'symbol': 'CVX',
#    'name': 'Convex Finance',
#    'supply': '96302631.1126707500000000',
#    'maxSupply': None,
#    'marketCapUsd': '356744939.9688714154018946',
#    'volumeUsd24Hr': '7486769.1190396955263292',
#    'priceUsd': '3.7044152983888069',
#    'changePercent24Hr': '8.2269910300758645',
#    'vwap24Hr': '3.3520028345824790',
#    'explorer': 'https://etherscan.io/token/0x4e3fbd56cd56c3e72c1403e103b45db9da5b9d2b'},
#   {'id': 'kusama',
#    'rank': '97',
#    'symbol': 'KSM',
#    'name': 'Kusama',
#    'supply': '15088279.5649121800000000',
#    'maxSupply': None,
#    'marketCapUsd': '349471660.1086840553163575',
#    'volumeUsd24Hr': '12785569.9358570465725382',
#    'priceUsd': '23.1617964530151602',
#    'changePercent24Hr': '-7.7056115412524627',
#    'vwap24Hr': '23.5083947780583449',
#    'explorer': 'https://kusama.subscan.io/'},
#   {'id': 'mantra-dao',
#    'rank': '98',
#    'symbol': 'OM',
#    'name': 'MANTRA DAO',
#    'supply': '500205033.1781248500000000',
#    'maxSupply': '888888888.0000000000000000',
#    'marketCapUsd': '334959430.4781882550084860',
#    'volumeUsd24Hr': '12428925.9734351301069726',
#    'priceUsd': '0.6696442623737214',
#    'changePercent24Hr': '-6.1937155468075482',
#    'vwap24Hr': '0.6808365030815907',
#    'explorer': 'https://etherscan.io/token/0x3593d125a4f7849a1b059e64f4517a86dd60c95d'},
#   {'id': 'zcash',
#    'rank': '99',
#    'symbol': 'ZEC',
#    'name': 'Zcash',
#    'supply': '16328268.7500000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '333990880.6408116891732900',
#    'volumeUsd24Hr': '38053304.8761202790528868',
#    'priceUsd': '20.4547638059185968',
#    'changePercent24Hr': '-9.4045102964297436',
#    'vwap24Hr': '20.4204533575074898',
#    'explorer': 'https://explorer.zcha.in/'},
#   {'id': 'superfarm',
#    'rank': '100',
#    'symbol': 'SUPER',
#    'name': 'SuperVerse',
#    'supply': '487776093.4169172600000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '332834891.1303905968698770',
#    'volumeUsd24Hr': '4444753.3603912443482864',
#    'priceUsd': '0.6823517913697881',
#    'changePercent24Hr': '-8.9593579525498273',
#    'vwap24Hr': '0.6821923944617103',
#    'explorer': 'https://etherscan.io/token/0xe53ec727dbdeb9e2d5456c3be40cff031ab40a55'}],
#  'timestamp': 1718743858828}

# %%
### Step 2: Transformation (Restructuring and Data Cleaning)

# %%
data = pd.json_normalize(responseData, "data")
data.head()
# Out:
#              id rank symbol      name                         supply  \
# 0       bitcoin    1    BTC   Bitcoin      19712456.0000000000000000
# 1      ethereum    2    ETH  Ethereum     120155065.8378261900000000
# 2        tether    3   USDT    Tether  112559949271.1193700000000000
# 3  binance-coin    4    BNB       BNB     166801148.0000000000000000
# 4        solana    5    SOL    Solana     461692203.9830211000000000
#
#                     maxSupply                    marketCapUsd  \
# 0   21000000.0000000000000000  1275281288696.3829619416614672
# 1                        None   413470522728.3945020622066917
# 2                        None   112620301682.7236352296714144
# 3  166801148.0000000000000000    97325646314.9792112012458140
# 4                        None    62689673531.5838326502084312
#
#                   volumeUsd24Hr                priceUsd    changePercent24Hr  \
# 0  14180570131.2609388223126685  64694.1856811948222962  -2.7641399840860026
# 1   9922297990.9760235603849082   3441.1409943086165660  -2.3446333320163117
# 2  24318625115.3766679453772541      1.0005361801599510   0.0224517489154227
# 3    558747509.2695132502606161    583.4830724005521305  -3.8703709497825942
# 4   1350543922.2140239577840725    135.7823956973058795  -5.2488381213590745
#
#                  vwap24Hr                                           explorer
# 0  65356.8947343889293355                           https://blockchain.info/
# 1   3439.1600170042335559                              https://etherscan.io/
# 2      1.0000683705887347             https://www.omniexplorer.info/asset/31
# 3    588.2794418423998908  https://etherscan.io/token/0xB8c77482e45F1F44d...
# 4    136.8886001167931171                       https://explorer.solana.com/

# %%
data.info()  # To get full data description, and find number of missing info!
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 100 non-null    object
#  1   rank               100 non-null    object
#  2   symbol             100 non-null    object
#  3   name               100 non-null    object
#  4   supply             100 non-null    object
#  5   maxSupply          36 non-null     object
#  6   marketCapUsd       100 non-null    object
#  7   volumeUsd24Hr      100 non-null    object
#  8   priceUsd           100 non-null    object
#  9   changePercent24Hr  100 non-null    object
#  10  vwap24Hr           99 non-null     object
#  11  explorer           99 non-null     object
# dtypes: object(12)
# memory usage: 9.5+ KB

# %%
### Step 3: Deal with missing data

# %%
def convert_columns_to_datatypes(df, column_datatypes):
    for column, datatype in column_datatypes.items():
        if column in df.columns:
            df[column] = df[column].astype(datatype)
    return df

# %%
column_datatypes = {
    'rank': int,   
    'supply': float,          
    'maxSupply': float,        
    'marketCapUsd': float,   
    'volumeUsd24Hr': float,      
    'priceUsd': float,          
    'changePercent24Hr': float,  
    'vwap24Hr': float           
}

data =  convert_columns_to_datatypes(data, column_datatypes)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 100 non-null    object
#  1   rank               100 non-null    int64
#  2   symbol             100 non-null    object
#  3   name               100 non-null    object
#  4   supply             100 non-null    float64
#  5   maxSupply          36 non-null     float64
#  6   marketCapUsd       100 non-null    float64
#  7   volumeUsd24Hr      100 non-null    float64
#  8   priceUsd           100 non-null    float64
#  9   changePercent24Hr  100 non-null    float64
#  10  vwap24Hr           99 non-null     float64
#  11  explorer           99 non-null     object
# dtypes: float64(7), int64(1), object(4)
# memory usage: 9.5+ KB

# %%
data["maxSupply"] = data["maxSupply"].fillna(0)
data["vwap24Hr"] = data["vwap24Hr"].fillna(0)
data["explorer"] = data["explorer"].fillna('na')

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 100 non-null    object
#  1   rank               100 non-null    int64
#  2   symbol             100 non-null    object
#  3   name               100 non-null    object
#  4   supply             100 non-null    float64
#  5   maxSupply          100 non-null    float64
#  6   marketCapUsd       100 non-null    float64
#  7   volumeUsd24Hr      100 non-null    float64
#  8   priceUsd           100 non-null    float64
#  9   changePercent24Hr  100 non-null    float64
#  10  vwap24Hr           100 non-null    float64
#  11  explorer           100 non-null    object
# dtypes: float64(7), int64(1), object(4)
# memory usage: 9.5+ KB

# %%
### Step 5: Round number to 2 decimal places

# %%
def round_to_two_decimal_places(number):
    return round(number, 2)

# %%
selected_columns = ['supply', 'maxSupply', 'marketCapUsd', 'priceUsd', 'changePercent24Hr', 'vwap24Hr']
data[selected_columns] = data[selected_columns].applymap(round_to_two_decimal_places)
data.head()
# Out:
# /var/folders/wr/jqy_t9_504552y6kfzk2s8kw0000gn/T/ipykernel_22148/1892541769.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   data[selected_columns] = data[selected_columns].applymap(round_to_two_decimal_places)
#              id  rank symbol      name        supply    maxSupply  \
# 0       bitcoin     1    BTC   Bitcoin  1.971246e+07   21000000.0
# 1      ethereum     2    ETH  Ethereum  1.201551e+08          0.0
# 2        tether     3   USDT    Tether  1.125599e+11          0.0
# 3  binance-coin     4    BNB       BNB  1.668011e+08  166801148.0
# 4        solana     5    SOL    Solana  4.616922e+08          0.0
#
#    marketCapUsd  volumeUsd24Hr  priceUsd  changePercent24Hr  vwap24Hr  \
# 0  1.275281e+12   1.418057e+10  64694.19              -2.76  65356.89
# 1  4.134705e+11   9.922298e+09   3441.14              -2.34   3439.16
# 2  1.126203e+11   2.431863e+10      1.00               0.02      1.00
# 3  9.732565e+10   5.587475e+08    583.48              -3.87    588.28
# 4  6.268967e+10   1.350544e+09    135.78              -5.25    136.89
#
#                                             explorer
# 0                           https://blockchain.info/
# 1                              https://etherscan.io/
# 2             https://www.omniexplorer.info/asset/31
# 3  https://etherscan.io/token/0xB8c77482e45F1F44d...
# 4                       https://explorer.solana.com/

# %%
### Step 6: Load the data into a Postgres Database

# %%
# !pip install pandas sqlalchemy psycopg2-binary
# Out:
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.11/site-packages (2.1.4)
# Requirement already satisfied: sqlalchemy in /opt/anaconda3/lib/python3.11/site-packages (2.0.25)
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.9-cp311-cp311-macosx_10_9_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: numpy<2,>=1.23.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from sqlalchemy) (4.9.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from sqlalchemy) (3.0.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading psycopg2_binary-2.9.9-cp311-cp311-macosx_10_9_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 9.0 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.9

# %%
# Databse Credentials
db_username = ''
db_password = ''
db_host = 'localhost'
db_port = 5432
db_name = ''

# %%
import psycopg2 # For connecting to PostgreSQL database and executing queries
from sqlalchemy import create_engine  # To efficiently manage and reuse database connections

# %%
connection_string = f'postgresql://{db_username}:{db_password}@{db_host}:{db_port}/{db_name}'

# %%
engine = create_engine(connection_string)

# %%
# Create a table name
table_name = 'Crypto_data'

# Load the data into the table
data.to_sql(table_name, engine, if_exists='replace', index=False)

#Close the engine connection
engine.dispose()
